# %%
import polars as pl

# %%
df = pl.read_parquet('../data/cleaned/application_test.parquet')

# %%
df.describe()
# Out:
# shape: (9, 122)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ statistic ┆ SK_ID_CUR ┆ NAME_CONT ┆ CODE_GEND ┆ … ┆ AMT_REQ_C ┆ AMT_REQ_C ┆ AMT_REQ_C ┆ AMT_REQ_ │
# │ ---       ┆ R         ┆ RACT_TYPE ┆ ER        ┆   ┆ REDIT_BUR ┆ REDIT_BUR ┆ REDIT_BUR ┆ CREDIT_B │
# │ str       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ EAU_WEEK  ┆ EAU_MON   ┆ EAU_QRT   ┆ UREAU_YE │
# │           ┆ f64       ┆ str       ┆ str       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ AR       │
# │           ┆           ┆           ┆           ┆   ┆ f64       ┆ f64       ┆ f64       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ count     ┆ 48744.0   ┆ 48744     ┆ 48744     ┆ … ┆ 42695.0   ┆ 42695.0   ┆ 42695.0   ┆ 42695.0  │
# ...
